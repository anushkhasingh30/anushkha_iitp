# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/content'

# %%
df=pd.read_csv('/content/kc_house_data.csv')

# %%
df
# Out:
#                id        date     price  ...     long  sqft_living15  sqft_lot15
# 0      7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1      6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2      5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3      2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4      1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
# ...           ...         ...       ...  ...      ...            ...         ...
# 21592   263000018   5/21/2014  360000.0  ... -122.346           1530        1509
# 21593  6600060120   2/23/2015  400000.0  ... -122.362           1830        7200
# 21594  1523300141   6/23/2014  402101.0  ... -122.299           1020        2007
# 21595   291310100   1/16/2015  400000.0  ... -122.069           1410        1287
# 21596  1523300157  10/15/2014  325000.0  ... -122.299           1020        1357
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21597.0  4.580474e+09  ...  7.308900e+09  9.900000e+09
# price          21597.0  5.402966e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21597.0  3.373200e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21597.0  2.115826e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21597.0  2.080322e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21597.0  1.509941e+04  ...  1.068500e+04  1.651359e+06
# floors         21597.0  1.494096e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21597.0  7.547345e-03  ...  0.000000e+00  1.000000e+00
# view           21597.0  2.342918e-01  ...  0.000000e+00  4.000000e+00
# condition      21597.0  3.409825e+00  ...  4.000000e+00  5.000000e+00
# grade          21597.0  7.657915e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21597.0  1.788597e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
df.head(3)
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
#
# [3 rows x 21 columns]

# %%
fig=plt.figure(figsize=(14,8))
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# some house has also 33 bedrooms max range
#that house of 33 bedrooms may be one so not highlighted in graph

# %%
df.corr()
# Out:
#                      id     price  ...  sqft_living15  sqft_lot15
# id             1.000000 -0.016772  ...      -0.002701   -0.138557
# price         -0.016772  1.000000  ...       0.585241    0.082845
# bedrooms       0.001150  0.308787  ...       0.393406    0.030690
# bathrooms      0.005162  0.525906  ...       0.569884    0.088303
# sqft_living   -0.012241  0.701917  ...       0.756402    0.184342
# sqft_lot      -0.131911  0.089876  ...       0.144763    0.718204
# floors         0.018608  0.256804  ...       0.280102   -0.010722
# waterfront    -0.002727  0.266398  ...       0.086507    0.030781
# view           0.011536  0.397370  ...       0.280681    0.072904
# condition     -0.023803  0.036056  ...      -0.093072   -0.003126
# grade          0.008188  0.667951  ...       0.713867    0.120981
# sqft_above    -0.010799  0.605368  ...       0.731767    0.195077
# sqft_basement -0.005193  0.323799  ...       0.200443    0.017550
# ...

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
#always check correlations between different features

# %%
fig=plt.figure(figsize=(10,4))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='price',y='long',data=df)

# %%
#looks like at long.=-122.2 there are many expensive houses

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='price',y='lat',data=df)

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
df.sort_values('price',ascending=False)
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245   6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910   9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245   9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407   2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446   8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
# ...           ...         ...        ...  ...      ...            ...         ...
# 2139   1623049041    5/8/2014    82500.0  ... -122.296           1572       10570
# 8267   3883800011   11/5/2014    82000.0  ... -122.341           1140       11250
# 16184  3028200080   3/24/2015    81000.0  ... -122.315            860        9000
# 465    8658300340   5/23/2014    80000.0  ... -121.909           1200        7500
# ...

# %%
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ex_expensive=df[df['price']<1000000]

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='long',y='lat',data=ex_expensive,hue='price',edgecolor=None,palette='RdYlGn',alpha=0.2)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['waterfront'].value_counts()
# Out:
# 0    21434
# 1      163
# Name: waterfront, dtype: int64

# %%
sns.boxplot(x='waterfront',y='price',data=df)
#if u are on the waterfront, prices are more expensive

# %%
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df=df.drop(['id'],axis=1)

# %%
df
# Out:
#              date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0      10/13/2014  221900.0         3  ... -122.257           1340        5650
# 1       12/9/2014  538000.0         3  ... -122.319           1690        7639
# 2       2/25/2015  180000.0         2  ... -122.233           2720        8062
# 3       12/9/2014  604000.0         4  ... -122.393           1360        5000
# 4       2/18/2015  510000.0         3  ... -122.045           1800        7503
# ...           ...       ...       ...  ...      ...            ...         ...
# 21592   5/21/2014  360000.0         3  ... -122.346           1530        1509
# 21593   2/23/2015  400000.0         4  ... -122.362           1830        7200
# 21594   6/23/2014  402101.0         2  ... -122.299           1020        2007
# 21595   1/16/2015  400000.0         3  ... -122.069           1410        1287
# 21596  10/15/2014  325000.0         2  ... -122.299           1020        1357
#
# ...

# %%
type(df['date'].iloc[1])
# Out:
# str

# %%
x=10/15/2014
k=pd.to_datetime(x)

# %%
k
# Out:
# Timestamp('1970-01-01 00:00:00')

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#             date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0     2014-10-13  221900.0         3  ... -122.257           1340        5650
# 1     2014-12-09  538000.0         3  ... -122.319           1690        7639
# 2     2015-02-25  180000.0         2  ... -122.233           2720        8062
# 3     2014-12-09  604000.0         4  ... -122.393           1360        5000
# 4     2015-02-18  510000.0         3  ... -122.045           1800        7503
# ...          ...       ...       ...  ...      ...            ...         ...
# 21592 2014-05-21  360000.0         3  ... -122.346           1530        1509
# 21593 2015-02-23  400000.0         4  ... -122.362           1830        7200
# 21594 2014-06-23  402101.0         2  ... -122.299           1020        2007
# 21595 2015-01-16  400000.0         3  ... -122.069           1410        1287
# 21596 2014-10-15  325000.0         2  ... -122.299           1020        1357
#
# [21597 rows x 20 columns]

# %%
df['year']=df['date'].apply(lambda x: x.year)

# %%
df
# Out:
#             date     price  bedrooms  ...  sqft_living15  sqft_lot15  year
# 0     2014-10-13  221900.0         3  ...           1340        5650  2014
# 1     2014-12-09  538000.0         3  ...           1690        7639  2014
# 2     2015-02-25  180000.0         2  ...           2720        8062  2015
# 3     2014-12-09  604000.0         4  ...           1360        5000  2014
# 4     2015-02-18  510000.0         3  ...           1800        7503  2015
# ...          ...       ...       ...  ...            ...         ...   ...
# 21592 2014-05-21  360000.0         3  ...           1530        1509  2014
# 21593 2015-02-23  400000.0         4  ...           1830        7200  2015
# 21594 2014-06-23  402101.0         2  ...           1020        2007  2014
# 21595 2015-01-16  400000.0         3  ...           1410        1287  2015
# 21596 2014-10-15  325000.0         2  ...           1020        1357  2014
#
# [21597 rows x 21 columns]

# %%
x=10/2/2023

# %%
import datetime

# %%
#help(datetime)

# %%
df['month']=df['date'].apply(lambda x: x.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year  month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
fig=plt.figure(figsize=(10,4))
sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby('year').mean()['price'].plot()

# %%
df=df.drop(['date'],axis=1)

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0      221900.0         3       1.00  ...        5650  2014     10
# 1      538000.0         3       2.25  ...        7639  2014     12
# 2      180000.0         2       1.00  ...        8062  2015      2
# 3      604000.0         4       3.00  ...        5000  2014     12
# 4      510000.0         3       2.00  ...        7503  2015      2
# ...         ...       ...        ...  ...         ...   ...    ...
# 21592  360000.0         3       2.50  ...        1509  2014      5
# 21593  400000.0         4       2.50  ...        7200  2015      2
# 21594  402101.0         2       0.75  ...        2007  2014      6
# 21595  400000.0         3       2.50  ...        1287  2015      1
# 21596  325000.0         2       0.75  ...        1357  2014     10
#
# [21597 rows x 21 columns]

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
#too many zipcodes to apply get_dummies on it

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df=df.drop(['zipcode'],axis=1)

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0      221900.0         3       1.00  ...        5650  2014     10
# 1      538000.0         3       2.25  ...        7639  2014     12
# 2      180000.0         2       1.00  ...        8062  2015      2
# 3      604000.0         4       3.00  ...        5000  2014     12
# 4      510000.0         3       2.00  ...        7503  2015      2
# ...         ...       ...        ...  ...         ...   ...    ...
# 21592  360000.0         3       2.50  ...        1509  2014      5
# 21593  400000.0         4       2.50  ...        7200  2015      2
# 21594  402101.0         2       0.75  ...        2007  2014      6
# 21595  400000.0         3       2.50  ...        1287  2015      1
# 21596  325000.0         2       0.75  ...        1357  2014     10
#
# [21597 rows x 20 columns]

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df.sort_values(by='sqft_basement',ascending=False)['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df.groupby('sqft_basement').mean()['price'].plot()

# %%
#model

# %%
X=df.drop(['price'],axis=1).values
y=df['price'].values

# %%
X
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 5.650e+03, 2.014e+03,
#         1.000e+01],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 7.639e+03, 2.014e+03,
#         1.200e+01],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 8.062e+03, 2.015e+03,
#         2.000e+00],
#        ...,
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 2.007e+03, 2.014e+03,
#         6.000e+00],
#        [3.000e+00, 2.500e+00, 1.600e+03, ..., 1.287e+03, 2.015e+03,
#         1.000e+00],
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 1.357e+03, 2.014e+03,
#         1.000e+01]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
X_test.shape
# Out:
# (6480, 19)

# %%
# Out:
# (21597, 19)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train=scaler.transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# %%
model.add(Dense(1))

# %%
model.compile('adam',loss='mse')

# %%
model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 4ms/step - loss: 71087448064.0000 - val_loss: 60603613184.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 56592351232.0000 - val_loss: 50368081920.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 49407647744.0000 - val_loss: 45633773568.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 45542035456.0000 - val_loss: 43002048512.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 42139279360.0000 - val_loss: 38938689536.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 39446790144.0000 - val_loss: 36779835392.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 37552754688.0000 - val_loss: 35144486912.0000
# Epoch 8/400
# 119/119 [==============================] - 0s 3ms/step - loss: 36537282560.0000 - val_loss: 34493370368.0000
# ...

# %%
X_test
# Out:
# array([[0.1       , 0.08      , 0.04239917, ..., 0.00887725, 0.        ,
#         0.63636364],
#        [0.3       , 0.36      , 0.17269907, ..., 0.00993734, 0.        ,
#         0.81818182],
#        [0.2       , 0.24      , 0.12512927, ..., 0.00547073, 0.        ,
#         0.90909091],
#        ...,
#        [0.1       , 0.08      , 0.05584281, ..., 0.00506255, 0.        ,
#         1.        ],
#        [0.3       , 0.2       , 0.22233713, ..., 0.00774485, 1.        ,
#         0.09090909],
#        [0.3       , 0.32      , 0.27611169, ..., 0.0196531 , 0.        ,
#         0.45454545]])
